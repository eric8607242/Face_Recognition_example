# %%
import os
import os.path as osp
import sys
sys.path.insert(0, osp.dirname(osp.abspath(".")))

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import torch
import torchvision.transforms as T
from torchvision.datasets import ImageFolder

from data.dataset.pair import PairFaceDataset

# %load_ext autoreload
# %autoreload 2

# %%
train_dataset = ImageFolder(root="../download/train/CASIA-WebFace/")
valid_dataset = PairFaceDataset(root="../download/test/CFP_FP/")

# %%
train_dataset[0][0]
# Out:
# <PIL.Image.Image image mode=RGB size=112x112 at 0x7FEA33708630>

# %%
valid_dataset[0][0][1]
# Out:
# <PIL.Image.Image image mode=RGB size=112x112 at 0x7FE92F8E5630>
