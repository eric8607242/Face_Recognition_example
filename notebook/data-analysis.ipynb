# %%
import os
import os.path as osp
import sys
sys.path.insert(0, osp.dirname(osp.abspath(".")))

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import torch
import torchvision.transforms as T
from torchvision.datasets import ImageFolder

from data.dataset.pair import PairFaceDataset

# %load_ext autoreload
# %autoreload 2

# %%
train_dataset = ImageFolder(root="../download/train/CASIA-WebFace/")

# %%
nrows = 5
ncols = 5

indices = np.arange(len(train_dataset))
np.random.shuffle(indices)
indices = indices[:nrows*ncols]
dataset = [ train_dataset[i] for i in indices ]

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(16, 16))

for i in range(nrows):
    for j in range(ncols):
        img = np.array(dataset[i*ncols+j][0])
        axes[i][j].imshow(img)
        axes[i][j].set_axis_off()

plt.tight_layout()
